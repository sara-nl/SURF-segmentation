# %%
from xmlpathology.xio.imagewriter import write_mask

from xmlpathology.xio.imageannotation import ImageAnnotation
label_map = {'dcis': 1, 'erythrocytes': 4, 'fatty tissue': 5, 'idc': 2, 'ilc': 3, 'inflammatory cells': 4, 'non malignant epithelium': 6, 'skin/nipple': 4, 'stroma': 4}

# %%
imageannotation = ImageAnnotation(1, '/home/mart/Radboudumc/site_openseadragon/T10-03264-I-8-1-gr2.tif', '/home/mart/Radboudumc/data/breast/level1/T10-03264-I-8-1-gr2.xml',label_map)

# %%
write_mask(imageannotation, spacing=0.5)
# Out:
# /home/mart/Radboudumc/site_openseadragon/T10-03264-I-8-1-gr2.tif
# writing...
# 0
# 1024
# 2048
# 3072
# 4096
# 5120
# 6144
# 7168
# 8192
# 9216
# 10240
# 11264
# 12288
# 13312
# 14336
# 15360
# 16384
# 17408
# 18432
# 19456
# 20480
# 21504
# 22528
# 23552
# 24576
# 25600
# 26624
# 27648
# 28672
# 29696
# 30720
# 31744
# 32768
# 33792
# 34816
# 35840
# 36864
# 37888
# 38912
# 39936
# 40960
# 41984
# 43008
# 44032
# 45056
# 46080
# 47104
# 48128
# 49152
# 50176
# 51200
# 52224
# 53248
# 54272
# 55296
# 56320
# 57344
# 58368
# 59392
# 60416
# 61440
# 62464
# 63488
# 64512
# 65536
# 66560
# 67584
# 68608
# 69632
# 70656
# 71680
# 72704
# 73728
# 74752
# 75776
# 76800
# 77824
# 78848
# 79872
# 80896
# 81920
# 82944
# 83968
# 84992
# 86016
# 87040
# 88064
# 89088
# 90112
# 91136
# 92160
# 93184
# 94208
# 95232
# 96256
# 97280
# 98304
# 99328
# 100352
# 101376
# 102400
# 103424
# 104448
# 105472
# 106496
# 107520
# 108544
# closing...
# done
